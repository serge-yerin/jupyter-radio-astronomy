# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(0)

dt = 0.01
Fs = 1/dt
t = np.arange(0, 10, dt)
nse = np.random.randn(len(t))
r = np.exp(-t/0.05)

cnse = np.convolve(nse, r)*dt
cnse = cnse[:len(t)]
s = 0.08*np.sin(5*np.pi*t) + cnse

plt.figure(1, figsize = [12,7], facecolor = 'white')

plt.subplot(3, 2, 1)
plt.plot(t, s)

plt.subplot(3, 2, 3)
plt.magnitude_spectrum(s, Fs=Fs)

plt.subplot(3, 2, 4)
plt.magnitude_spectrum(s, Fs=Fs, scale='dB')

plt.subplot(3, 2, 5)
plt.angle_spectrum(s, Fs=Fs)

plt.subplot(3, 2, 6)
plt.phase_spectrum(s, Fs=Fs)

plt.show()

# %%
points=np.linspace(1,30,1000)

# %%
signal = np.sin(points)
plt.plot(signal)

# %%
mean = 0
std = 1 
noise = np.random.normal(mean, std, len(points))
plt.plot(noise)

# %%
mix01 = 2*signal + noise
mix02 = 0.3*signal + 1.0*noise
plt.plot (mix01)

# %%
plt.plot (mix02)
